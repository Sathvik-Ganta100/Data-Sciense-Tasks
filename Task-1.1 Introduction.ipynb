# %% [markdown]
# # Python Introduction

# %%
import sys
sys.version          # To check our python version
# Out:
# '3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# ## How to write Coments

# %%
# Using hash we can write single write comment 

"""
Using a triple of single quotes (''' ''')
   or a triple of single quotes (""" """)
 
we can write multiline comment
"""
# Out:
# "\nUsing a triple of single quotes (''' ''')\n   or a triple of single quotes ()\n \nwe can write multiline comment\n"

# %%
'welcome to fsds with Chatgpt @ 10:00 Am'
# Out:
# 'welcome to fsds with Chatgpt @ 10:00 Am'

# %% [markdown]
# SyntaxError: unterminated string literal - Missing single( ' ) or double( " ) quotes

# %%
'welcome to fsds with Chatgpt @ 10:00 Am
# Out:
#   Cell In[4], line 1
#     'welcome to fsds with Chatgpt @ 10:00 Am
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Python identifier = Object = variable

# %% [raw]
# syntax
# <identifier name> = value

# %%
x = 5   # x - identifier & 5 - value

# %% [markdown]
# ## Variable & Function
#
# Variable is a container to store values
#
# functions always ends with ( )

# %% [raw]
# a = 5
#
# a is identifier | Object | variable

# %% [raw]
# a()
#
# a is function

# %%
a = 9        # Integer (Int)
b = 4.7      # Float   (float)
c = 'NIT'    # String  (str)
d = True     # Boolean (bool)

# %%
print(type(a))  # type() ---> gives type of data type
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a, b, c, d
# Out:
# (9, 4.7, 'NIT', True)

# %%
print(id(a))   # id() ---> Unique identity of the object
# Out:
# 2123788976624

# %%
a, b, c, d
# Out:
# (9, 4.7, 'NIT', True)

# %%
L = [10, 20, 30, 40,50]
print(type(L))
print(len(L))           # len() ---> gives length of data type
# Out:
# <class 'list'>
# 5

# %% [raw]
# in build functions ---> print() | len() | type() | id()
